# %% [markdown]
# #### Environment Configuration
#
# This notebook stores **shared variables** used across the entire Formula 1 project. Instead of typing catalog names, schema names, and file paths in every notebook, we define them here once.
#
# **How it works:** Other notebooks call `%run` on this file, which loads all these variables into their session - like importing a settings file.
#
# | Variable | What it stores |
# | --- | --- |
# | `catalog_name` | The Unity Catalog name (`formula1`) |
# | `bronze_schema` | Schema for raw loaded data |
# | `silver_schema` | Schema for cleaned data |
# | `gold_schema` | Schema for final aggregated data |
# | `loding_folder_path` | Path to the raw CSV files in the landing volume |

# %%
# Unit Catalog object Names
catalog_name = "formula1"
bronze_schema = "bronze"
silver_schema = "silver"
gold_schema = "gold"

# %%
loding_folder_path='/Volumes/formula1/landing/files'
