# %% [markdown]
# #### Environment Configuration

# %%
# Unit Catalog object Names
catalog_name = "formula1_incr"
bronze_schema = "bronze"
silver_schema = "silver"
gold_schema = "gold"
control_schema = "control"

# %%
loding_folder_path = '/Volumes/formula1_incr/landing/files'
