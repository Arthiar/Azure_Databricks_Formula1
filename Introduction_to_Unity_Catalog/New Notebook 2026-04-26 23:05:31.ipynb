# %% [markdown]
# # Check Unity Catalog Connection
#
# This quick check confirms that your Databricks workspace is properly connected to a **Unity Catalog metastore**.
#
# A metastore is the central place that stores all your data governance information (catalogs, schemas, tables, permissions). If this query returns a metastore ID, it means everything is set up correctly.

# %%
# %sql
select current_metastore()
