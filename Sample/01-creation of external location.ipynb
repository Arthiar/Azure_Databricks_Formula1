# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS demopurpose
    URL 'abfss://demopurpose@arthisc.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL `arthis-test-sc`)

# %%
# %sql
CREATE CATALOG IF NOT EXISTS newproject
    MANAGED LOCATION 'abfss://demopurpose@arthisc.dfs.core.windows.net/newproject'
